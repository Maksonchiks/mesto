# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/churn.csv")
df.head(12)
# Out:
#                 churn  Customer_Age Gender  Dependent_count Education_Level  \
# 0   Existing Customer          45.0      M              3.0     High School
# 1   Existing Customer          49.0      F              5.0        Graduate
# 2   Existing Customer          51.0      M              3.0        Graduate
# 3   Existing Customer          40.0      F              4.0     High School
# 4   Existing Customer          40.0      M              3.0      Uneducated
# 5   Existing Customer          44.0      M              2.0        Graduate
# 6   Existing Customer          51.0      M              4.0         Unknown
# 7   Existing Customer          32.0      M              0.0     High School
# 8   Existing Customer          37.0      M              3.0      Uneducated
# 9   Existing Customer          48.0      M              2.0        Graduate
# 10  Existing Customer          42.0      M              5.0      Uneducated
# 11  Existing Customer          65.0      M              1.0         Unknown
#
#    Marital_Status Income_Category Card_Category  Months_on_book  \
# 0         Married     $60K - $80K          Blue            39.0
# 1          Single  Less than $40K          Blue            44.0
# 2         Married    $80K - $120K          Blue            36.0
# 3         Unknown  Less than $40K          Blue            34.0
# 4         Married     $60K - $80K          Blue            21.0
# 5         Married     $40K - $60K          Blue            36.0
# 6         Married         $120K +          Gold            46.0
# 7         Unknown     $60K - $80K        Silver            27.0
# 8          Single     $60K - $80K          Blue            36.0
# 9          Single    $80K - $120K          Blue            36.0
# 10        Unknown         $120K +          Blue            31.0
# 11        Married     $40K - $60K          Blue            54.0
#
#     Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                        5.0                     1.0                    3.0
# 1                        6.0                     1.0                    2.0
# 2                        4.0                     1.0                    0.0
# 3                        3.0                     4.0                    1.0
# 4                        5.0                     1.0                    0.0
# 5                        3.0                     1.0                    2.0
# 6                        6.0                     1.0                    3.0
# 7                        2.0                     2.0                    2.0
# 8                        5.0                     2.0                    0.0
# 9                        6.0                     3.0                    3.0
# 10                       5.0                     3.0                    2.0
# 11                       6.0                     2.0                    3.0
#
#     Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0        12691.0                777.0          11914.0                 1.335
# 1         8256.0                864.0           7392.0                 1.541
# 2         3418.0                  0.0           3418.0                 2.594
# 3         3313.0               2517.0            796.0                 1.405
# 4         4716.0                  0.0           4716.0                 2.175
# 5         4010.0               1247.0           2763.0                 1.376
# 6        34516.0               2264.0          32252.0                 1.975
# 7        29081.0               1396.0          27685.0                 2.204
# 8        22352.0               2517.0          19835.0                 3.355
# 9        11656.0               1677.0           9979.0                 1.524
# 10        6748.0               1467.0           5281.0                 0.831
# 11        9095.0               1587.0           7508.0                 1.433
#
#     Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0            1144.0            42.0                1.625
# 1            1291.0            33.0                3.714
# 2            1887.0            20.0                2.333
# 3            1171.0            20.0                2.333
# 4             816.0            28.0                2.500
# 5            1088.0            24.0                0.846
# 6            1330.0            31.0                0.722
# 7            1538.0            36.0                0.714
# 8            1350.0            24.0                1.182
# 9            1441.0            32.0                0.882
# 10           1201.0            42.0                0.680
# 11           1314.0            26.0                1.364
#
#     Avg_Utilization_Ratio
# 0                   0.061
# 1                   0.105
# 2                   0.000
# 3                   0.760
# 4                   0.000
# 5                   0.311
# 6                   0.066
# 7                   0.048
# 8                   0.113
# 9                   0.144
# 10                  0.217
# 11                  0.174

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8562 entries, 0 to 8561
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   churn                     8562 non-null   object
#  1   Customer_Age              8561 non-null   float64
#  2   Gender                    8561 non-null   object
#  3   Dependent_count           8561 non-null   float64
#  4   Education_Level           8561 non-null   object
#  5   Marital_Status            8561 non-null   object
#  6   Income_Category           8561 non-null   object
#  7   Card_Category             8561 non-null   object
#  8   Months_on_book            8561 non-null   float64
#  9   Total_Relationship_Count  8561 non-null   float64
#  10  Months_Inactive_12_mon    8561 non-null   float64
#  11  Contacts_Count_12_mon     8561 non-null   float64
#  12  Credit_Limit              8561 non-null   float64
#  13  Total_Revolving_Bal       8561 non-null   float64
#  14  Avg_Open_To_Buy           8561 non-null   float64
#  15  Total_Amt_Chng_Q4_Q1      8561 non-null   float64
#  16  Total_Trans_Amt           8561 non-null   float64
#  17  Total_Trans_Ct            8561 non-null   float64
#  18  Total_Ct_Chng_Q4_Q1       8561 non-null   float64
#  19  Avg_Utilization_Ratio     8561 non-null   float64
# dtypes: float64(14), object(6)
# memory usage: 1.3+ MB

# %%
# df=df.replace({'Unknown':np.NaN})

# %%
# sns.heatmap(df.isnull(),cmap='copper')

# %%
# num_nulls_educate=df["Education_Level"].isnull().sum()
# print("Количество пустых ячеек а колонке 'Education_Level':", num_nulls_educate)
# num_nulls_marital=df["Marital_Status"].isnull().sum()
# print("Количество пустых ячеек а колонке 'Marital_Status ':", num_nulls_marital )
# num_nulls_income=df["Income_Category"].isnull().sum()
# print("Количество пустых ячеек а колонке 'Income_Category':", num_nulls_income)

# %%
duplecates = df.duplicated().sum()
print("Кол-во дупликатов: ",duplecates)
# Out:
# Кол-во дупликатов:  0

# %%
df_setect_out=df[['Customer_Age','Credit_Limit','Dependent_count','Months_on_book','Total_Relationship_Count']]
df_setect_out
# Out:
#       Customer_Age  Credit_Limit  Dependent_count  Months_on_book  \
# 0             45.0       12691.0              3.0            39.0
# 1             49.0        8256.0              5.0            44.0
# 2             51.0        3418.0              3.0            36.0
# 3             40.0        3313.0              4.0            34.0
# 4             40.0        4716.0              3.0            21.0
# ...            ...           ...              ...             ...
# 8557          42.0       13426.0              4.0            38.0
# 8558          48.0        9104.0              3.0            43.0
# 8559          47.0       30300.0              2.0            35.0
# 8560          51.0        7088.0              3.0            39.0
# 8561           NaN           NaN              NaN             NaN
#
#       Total_Relationship_Count
# 0                          5.0
# 1                          6.0
# 2                          4.0
# 3                          3.0
# 4                          5.0
# ...                        ...
# 8557                       2.0
# 8558                       2.0
# 8559                       1.0
# 8560                       1.0
# 8561                       NaN
#
# [8562 rows x 5 columns]

# %%
outlier_cols = []

for column in df_setect_out.columns:
    Q1 = df_setect_out[column].quantile(0.25)
    Q3 = df_setect_out[column].quantile(0.75)
    IQR = Q3 - Q1

    outliers = (df_setect_out[column] < Q1 - 1.5 * IQR) | (df_setect_out[column] > Q3 + 1.5 * IQR)

    if any(outliers):
        outlier_cols.append(column)

print("Columns with outliers:", outlier_cols)
# Out:
# Columns with outliers: ['Customer_Age', 'Credit_Limit', 'Months_on_book']

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(df_setect_out.columns), figsize=(15, 5))

for i, column in enumerate(df_setect_out.columns):
    sns.boxplot(x=df_setect_out[column], ax=axes[i], color='skyblue')
    axes[i].set_title(f'Box Plot for {column}')

plt.tight_layout()
plt.show()

# %%
data = {
    'Customer_Age': [26, 30, 40, 50, 60, 68, 73],
    'Credit_Limit': [1700, 2000,  5000, 10000,  15000, 20000, 39000 ],
    'Month_on_book': [13, 25, 30, 40, 45, 50, 56],
}

df_select_out = pd.DataFrame(data)

def replace_outliers(column, replace_value):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    column.loc[(column < lower_bound) | (column > upper_bound)] = replace_value

for col in ['Customer_Age', 'Credit_Limit', 'Month_on_book']:
    replace_outliers(df_select_out[col], replace_value=df_select_out[col].median())

# %%
average_age = df.groupby('Customer_Age')['Credit_Limit'].mean().reset_index()
average_age
# Out:
#     Customer_Age  Credit_Limit
# 0           26.0   4591.953846
# 1           27.0   3694.756000
# 2           28.0   8241.125000
# 3           29.0   6597.169231
# 4           30.0   5844.544231
# 5           31.0   5579.235714
# 6           32.0   6865.308219
# 7           33.0   6642.440000
# 8           34.0   6543.565649
# 9           35.0   6633.979412
# 10          36.0   6676.676847
# 11          37.0   6328.232203
# 12          38.0   7439.586154
# 13          39.0   7243.043060
# 14          40.0   8696.953846
# 15          41.0   8383.265584
# 16          42.0   7513.768245
# 17          43.0   8512.647044
# 18          44.0   8107.647174
# 19          45.0   8015.929557
# 20          46.0   8288.528293
# 21          47.0   7699.371111
# 22          48.0   8427.547772
# 23          49.0   8201.342317
# 24          50.0   8210.573404
# 25          51.0   8460.670000
# 26          52.0   8544.374841
# 27          53.0   7318.072156
# 28          54.0   6855.741758
# 29          55.0   8190.144939
# 30          56.0   6039.953846
# 31          57.0   7865.555897
# 32          58.0   7139.287500
# 33          59.0   5512.111194
# 34          60.0   6177.369903
# 35          61.0   5923.546753
# 36          62.0   7496.694253
# 37          63.0   7232.998413
# 38          64.0   4139.588372
# 39          65.0   5620.509901
# 40          66.0   5526.500000
# 41          67.0   5624.250000
# 42          68.0   7649.150000
# 43          70.0   3252.000000
# 44          73.0   4469.000000

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Customer_Age', y='Credit_Limit', data=average_age)
plt.title('Кредитный лимит по возрасту')
plt.xlabel('Возраст')
plt.ylabel('Кредитный лимит')
plt.xticks(rotation=90)

plt.show()

# %%
min_age = average_age.loc[average_age['Credit_Limit'].idxmin(), 'Customer_Age']
max_age = average_age.loc[average_age['Credit_Limit'].idxmax(), 'Customer_Age']

min_credit = average_age['Credit_Limit'].min()
max_credit = average_age['Credit_Limit'].max()

print(f'Минимальный кредитный лимит: {min_credit} в возрасте: {min_age}')
print(f'Максимальный кредитный лимит: {max_credit} в возрасте: {max_age}')
# Out:
# Минимальный кредитный лимит: 3252.0 в возрасте: 70.0
# Максимальный кредитный лимит: 8696.953846153847 в возрасте: 40.0

# %%
edu_counts = df['Education_Level'].value_counts().reset_index()

edu_counts.columns = ['Education_Level', 'Count']
print(edu_counts)
# Out:
#   Education_Level  Count
# 0        Graduate   2641
# 1     High School   1709
# 2         Unknown   1280
# 3      Uneducated   1244
# 4         College    873
# 5   Post-Graduate    420
# 6       Doctorate    394

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8, 6))
ax = sns.barplot(x ='Count', y='Education_Level', data=edu_counts, palette='copper')
plt.xlabel("Количество людей")
plt.ylabel("Уровень образования")
plt.title("Сравнение количества людей с разным уровнем образования")

plt.show()
# Out:
# <ipython-input-13-aa95937a5b4a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x ='Count', y='Education_Level', data=edu_counts, palette='copper')

# %%
corr = df['Customer_Age'].corr(df['Months_on_book'])
print("Кореляция между возрастом пользователя и периодом его взаимоотношений в банке: {:.3f}".format(corr))
# Out:
# Кореляция между возрастом пользователя и периодом его взаимоотношений в банке: 0.792

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x=df['Customer_Age'], y=df['Months_on_book'], palette = 'twilight')
plt.title('Кореляция между возрастом и приодом взаимодействия с банком')
plt.ylabel('Период')
plt.xlabel('Возраст')
plt.xticks(rotation=90)

plt.show()
# Out:
# <ipython-input-15-91ab84392a6f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df['Customer_Age'], y=df['Months_on_book'], palette = 'twilight')

# %%
marital_count = df['Marital_Status'].value_counts()
marital_count
# Out:
# Marital_Status
# Married     4023
# Single      3300
# Divorced     629
# Unknown      609
# Name: count, dtype: int64

# %%
plt.figure(figsize =(8,8))
plt.pie(marital_count, labels=marital_count.index, autopct = '%1.1f%%', startangle=140, colors = plt.cm.Pastel1.colors)

centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend()
plt.title('Сравнение статуса семейной жизни человека')
plt.show()

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
ordinal_encoder = OrdinalEncoder()
encoded_data = ordinal_encoder.fit_transform(df[categorical_columns])
df[categorical_columns] = encoded_data.astype(int)
df
# Out:
# <ipython-input-18-a1cb0470afad>:6: RuntimeWarning: invalid value encountered in cast
#   df[categorical_columns] = encoded_data.astype(int)
#       churn  Customer_Age               Gender  Dependent_count  \
# 0         2          45.0                    1              3.0
# 1         2          49.0                    0              5.0
# 2         2          51.0                    1              3.0
# 3         2          40.0                    0              4.0
# 4         2          40.0                    1              3.0
# ...     ...           ...                  ...              ...
# 8557      2          42.0                    1              4.0
# 8558      0          48.0                    1              3.0
# 8559      2          47.0                    1              2.0
# 8560      2          51.0                    1              3.0
# 8561      1           NaN -9223372036854775808              NaN
#
#           Education_Level       Marital_Status      Income_Category  \
# 0                       3                    1                    2
# 1                       2                    2                    4
# 2                       2                    1                    3
# 3                       3                    3                    4
# 4                       5                    1                    2
# ...                   ...                  ...                  ...
# 8557                    3                    1                    2
# 8558                    2                    0                    1
# 8559                    4                    1                    3
# 8560                    2                    1                    3
# 8561 -9223372036854775808 -9223372036854775808 -9223372036854775808
#
#             Card_Category  Months_on_book  Total_Relationship_Count  \
# 0                       0            39.0                       5.0
# 1                       0            44.0                       6.0
# 2                       0            36.0                       4.0
# 3                       0            34.0                       3.0
# 4                       0            21.0                       5.0
# ...                   ...             ...                       ...
# 8557                    0            38.0                       2.0
# 8558                    0            43.0                       2.0
# 8559                    0            35.0                       1.0
# 8560                    0            39.0                       1.0
# 8561 -9223372036854775808             NaN                       NaN
#
#       Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                        1.0                    3.0       12691.0
# 1                        1.0                    2.0        8256.0
# 2                        1.0                    0.0        3418.0
# 3                        4.0                    1.0        3313.0
# 4                        1.0                    0.0        4716.0
# ...                      ...                    ...           ...
# 8557                     2.0                    2.0       13426.0
# 8558                     3.0                    3.0        9104.0
# 8559                     3.0                    1.0       30300.0
# 8560                     2.0                    1.0        7088.0
# 8561                     NaN                    NaN           NaN
#
#       Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                   777.0          11914.0                 1.335
# 1                   864.0           7392.0                 1.541
# 2                     0.0           3418.0                 2.594
# 3                  2517.0            796.0                 1.405
# 4                     0.0           4716.0                 2.175
# ...                   ...              ...                   ...
# 8557                  0.0          13426.0                 0.717
# 8558                145.0           8959.0                 0.765
# 8559               1166.0          29134.0                 0.715
# 8560               1750.0           5338.0                 0.618
# 8561                  NaN              NaN                   NaN
#
#       Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0              1144.0            42.0                1.625
# 1              1291.0            33.0                3.714
# 2              1887.0            20.0                2.333
# 3              1171.0            20.0                2.333
# 4               816.0            28.0                2.500
# ...               ...             ...                  ...
# 8557           4674.0            66.0                0.886
# 8558           2563.0            34.0                0.417
# 8559           4146.0            64.0                0.882
# 8560           4691.0            76.0                0.727
# 8561              NaN             NaN                  NaN
#
#       Avg_Utilization_Ratio
# 0                     0.061
# 1                     0.105
# 2                     0.000
# 3                     0.760
# 4                     0.000
# ...                     ...
# 8557                  0.000
# 8558                  0.016
# 8559                  0.038
# 8560                  0.247
# 8561                    NaN
#
# [8562 rows x 20 columns]

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr())
# Out:
# <Axes: >
